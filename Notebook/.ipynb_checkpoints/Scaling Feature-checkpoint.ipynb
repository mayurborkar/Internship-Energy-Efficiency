# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Lenovo\PycharmProjects\EnergyEfficiency\Dataset\Scaling.csv")
df.head()
# Out:
#    Unnamed: 0  relative compactness  surface area  wall area  roof area  \
# 0           0                  0.98         514.5      294.0     110.25
# 1           1                  0.98         514.5      294.0     110.25
# 2           2                  0.98         514.5      294.0     110.25
# 3           3                  0.98         514.5      294.0     110.25
# 4           4                  0.90         563.5      318.5     122.50
#
#    overall height  orientation  glazing area  glazing area distribution  \
# 0             7.0            2           0.0                          0
# 1             7.0            3           0.0                          0
# 2             7.0            4           0.0                          0
# 3             7.0            5           0.0                          0
# 4             7.0            2           0.0                          0
#
#    heating load  cooling load
# 0         15.55         21.33
# 1         15.55         21.33
# 2         15.55         21.33
# 3         15.55         21.33
# 4         20.84         28.28

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    relative compactness  surface area  wall area  roof area  overall height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    orientation  glazing area  glazing area distribution  heating load  \
# 0            2           0.0                          0         15.55
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84
#
#    cooling load
# 0         21.33
# 1         21.33
# 2         21.33
# 3         21.33
# 4         28.28

# %%
scaling_feature =[feature for feature in df.columns if feature not in ['cooling load','heating load']]
df[scaling_feature].head()
# Out:
#    relative compactness  surface area  wall area  roof area  overall height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    orientation  glazing area  glazing area distribution
# 0            2           0.0                          0
# 1            3           0.0                          0
# 2            4           0.0                          0
# 3            5           0.0                          0
# 4            2           0.0                          0

# %%
scaler = MinMaxScaler()
data = scaler.fit_transform(df[scaling_feature])
data
# Out:
# array([[1.        , 0.        , 0.28571429, ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.        , 0.28571429, ..., 0.33333333, 0.        ,
#         0.        ],
#        [1.        , 0.        , 0.28571429, ..., 0.66666667, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 1.        , 0.71428571, ..., 0.33333333, 1.        ,
#         1.        ],
#        [0.        , 1.        , 0.71428571, ..., 0.66666667, 1.        ,
#         1.        ],
#        [0.        , 1.        , 0.71428571, ..., 1.        , 1.        ,
#         1.        ]])

# %%
data.shape
# Out:
# (768, 8)

# %%
VIF = pd.DataFrame()
VIF['vif'] = [variance_inflation_factor (data,i) for i in range(data.shape[1])]
VIF['feature'] = df[scaling_feature].columns
VIF
# Out:
#             vif                    feature
# 0    105.524054       relative compactness
# 1  31190.507641               surface area
# 2   5459.755056                  wall area
# 3  17319.814328                  roof area
# 4     31.205474             overall height
# 5      1.000000                orientation
# 6      1.047508               glazing area
# 7      1.047508  glazing area distribution

# %% [markdown]
# **As we see that from VIF the value will be beyond 10. So we decide to perform an analysis designed for highly correlated variables, such as Principal Components Analysis**

# %%
pca=PCA()
data2=pca.fit_transform(data)
data2
# Out:
# array([[ 1.06199953e+00, -5.00000000e-01,  8.04194062e-01, ...,
#          1.87998678e-01, -1.94322702e-02,  2.91999582e-15],
#        [ 1.06199953e+00, -1.66666667e-01,  8.04194062e-01, ...,
#          1.87998678e-01, -1.94322702e-02, -9.75184846e-17],
#        [ 1.06199953e+00,  1.66666667e-01,  8.04194062e-01, ...,
#          1.87998678e-01, -1.94322702e-02, -9.00402463e-17],
#        ...,
#        [-8.45733471e-01, -1.66666667e-01, -5.91673381e-01, ...,
#          4.46380243e-02, -3.77684211e-02, -7.21308046e-17],
#        [-8.45733471e-01,  1.66666667e-01, -5.91673381e-01, ...,
#          4.46380243e-02, -3.77684211e-02, -6.73364485e-17],
#        [-8.45733471e-01,  5.00000000e-01, -5.91673381e-01, ...,
#          4.46380243e-02, -3.77684211e-02, -6.25420924e-17]])

# %%
data2.shape
# Out:
# (768, 8)

# %%
VIF = pd.DataFrame()
VIF['vif'] = [variance_inflation_factor (data2,i) for i in range(data2.shape[1])]
VIF['feature'] = df[scaling_feature].columns
VIF
# Out:
#    vif                    feature
# 0  1.0       relative compactness
# 1  1.0               surface area
# 2  1.0                  wall area
# 3  1.0                  roof area
# 4  1.0             overall height
# 5  1.0                orientation
# 6  1.0               glazing area
# 7  1.0  glazing area distribution

# %%
one = df[['heating load','cooling load']]

# %%
two = pd.DataFrame(data2,columns=df[scaling_feature].columns)

# %%
df_new = pd.concat([one,two],axis=1)
df_new.head()
# Out:
#    heating load  cooling load  relative compactness  surface area  wall area  \
# 0         15.55         21.33              1.062000     -0.500000   0.804194
# 1         15.55         21.33              1.062000     -0.166667   0.804194
# 2         15.55         21.33              1.062000      0.166667   0.804194
# 3         15.55         21.33              1.062000      0.500000   0.804194
# 4         20.84         28.28              0.868368     -0.500000   0.804194
#
#    roof area  overall height  orientation  glazing area  \
# 0  -0.338293       -0.114022     0.187999     -0.019432
# 1  -0.338293       -0.114022     0.187999     -0.019432
# 2  -0.338293       -0.114022     0.187999     -0.019432
# 3  -0.338293       -0.114022     0.187999     -0.019432
# 4  -0.095116       -0.114022     0.074478      0.000547
#
#    glazing area distribution
# 0               2.919996e-15
# 1              -9.751848e-17
# 2              -9.004025e-17
# 3              -1.349037e-16
# 4               5.217437e-17

# %%
#df_new.to_csv(r'C:\Users\Lenovo\PycharmProjects\EnergyEfficiency\Dataset\Model_Building.csv')

# %%
import pickle
file = 'Energy_Efficiency_pca.pkl'

pickle.dump(pca, open(file,'wb'))
